# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/GPT-Insights/blob/main/o1-planning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai==1.54.0 httpx==0.27.2

# %%
from google.colab import userdata
import os

# userdata.get('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
from openai import OpenAI

client = OpenAI(api_key=openai_api_key)

prompt = """
I want to build a Python app that takes user questions and looks
them up in a database where they are mapped to answers. If there
is close match, it retrieves the matched answer. If there isn't,
it asks the user to provide an answer and stores the
question/answer pair in the database. Make a plan for the directory
structure you'll need, then return each file in full. Only supply
your reasoning at the beginning and end, not throughout the code.
"""

response = client.chat.completions.create(
    model="o1-preview",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": prompt
                },
            ],
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# **Plan and Directory Structure:**
#
# To build the Python application that answers user questions by looking them up in a database, we'll structure the project as follows:
#
# ```
# my_app/
# ├── app.py
# ├── database.py
# ├── matching.py
# ├── requirements.txt
# └── data/
#     └── qa_database.db
# ```
#
# - **app.py**: The main application script that handles user interaction.
# - **database.py**: Module for database operations (creation, insertion, querying).
# - **matching.py**: Module containing functions to find the closest match to the user's question.
# - **requirements.txt**: Lists the dependencies required by the application.
# - **data/**: Directory to store the SQLite database file.
#
# ---
#
# **Files:**
#
# ---
#
# **`requirements.txt`**
#
# ```
# rapidfuzz
# ```
#
# ---
#
# **`database.py`**
#
# ```python
# import sqlite3
#
# def create_connection(db_file):
#     """Create a database connection to the SQLite database."""
#     conn = sqlite3.connect(db_file)
#     return conn
#
# def create_table(conn):
#     """Create the qa_pairs table if it doesn't exist."""
#     sql_create_qa_table = '''
#     CREATE TABLE IF NOT EXISTS qa_pairs (
#         id INTEGER PRIMARY KEY AUTOINCREMENT,
#         question TEXT NOT NULL,
#         answer TEXT NOT NULL
#     );
#     '''
#     cursor = conn.cursor()
#     cursor.execute(sql_create_qa_table)
#     conn.commit()
#
# def insert_qa_pair(conn, question, answer):
#     """Insert a new question-answer pair into the qa_pairs table."""
#     sql = '''
#     INSERT INTO qa_pairs (question, answer)
#     VALUES (?, ?)
#     '''
#     cursor = conn.cursor()
#     cursor.execute(sql, (question, answer))
#     conn.commit()
#
# def get_all_questions(conn):
#     """Retrieve all questions from the qa_pairs table."""
#     sql = 'SELECT question FROM qa_pairs'
#     cursor = conn.cursor()
#     cursor.execute(sql)
#     rows = cursor.fetchall()
#     return [row[0] for row in rows]
#
# def get_answer_by_question(conn, question):
#     """Retrieve the answer corresponding to a question."""
#     sql = 'SELECT answer FROM qa_pairs WHERE question = ?'
#     cursor = conn.cursor()
#     cursor.execute(sql, (question,))
#     result = cursor.fetchone()
#     if result:
#         return result[0]
#     else:
#         return None
# ```
#
# ---
#
# **`matching.py`**
#
# ```python
# from rapidfuzz import process
#
# def find_closest_match(input_question, question_list):
#     """
#     Find the closest match to the input_question from the question_list.
#     Returns the best match and its similarity score.
#     """
#     match, score, _ = process.extractOne(input_question, question_list)
#     return match, score
# ```
#
# ---
#
# **`app.py`**
#
# ```python
# import os
# from database import (
#     create_connection,
#     create_table,
#     insert_qa_pair,
#     get_all_questions,
#     get_answer_by_question
# )
# from matching import find_closest_match
#
# def main():
#     db_path = 'data'
#     if not os.path.exists(db_path):
#         os.makedirs(db_path)
#     db_file = os.path.join(db_path, 'qa_database.db')
#
#     # Establish database connection and ensure table exists
#     conn = create_connection(db_file)
#     create_table(conn)
#
#     print("Welcome to the Question Answering App!")
#
#     while True:
#         user_question = input("\nPlease enter your question (or type 'exit' to quit): ")
#         if user_question.lower() == 'exit':
#             print("Goodbye!")
#             break
#
#         questions = get_all_questions(conn)
#         if questions:
#             closest_question, score = find_closest_match(user_question, questions)
#             if score > 80:  # Adjust the threshold as needed
#                 answer = get_answer_by_question(conn, closest_question)
#                 print(f"\nFound a close match (Score: {score:.2f}%):")
#                 print(f"Question: {closest_question}")
#                 print(f"Answer: {answer}")
#             else:
#                 print("\nNo close match found.")
#                 user_answer = input("Please provide an answer to your question: ")
#                 insert_qa_pair(conn, user_question, user_answer)
#                 print("Your question and answer have been saved.")
#         else:
#             print("\nNo questions in the database yet.")
#             user_answer = input("Please provide an answer to your question: ")
#             insert_qa_pair(conn, user_question, user_answer)
#             print("Your question and answer have been saved.")
#
#     conn.close()
#
# if __name__ == '__main__':
#     main()
# ```
#
# ---
#
# **Final Remarks:**
#
# This application allows you to input questions and attempts to find close matches from a database of question-answer pairs. If a close match is found (with a similarity score above 80%), it retrieves and displays the corresponding answer. If no close match is found, it prompts you to provide an answer, which is then stored in the database for future queries.
#
# **Instructions to Run the Application:**
#
# 1. **Install Dependencies**
#
#    Ensure you have Python installed (version 3.x). Install the required packages using:
#
#    ```
#    pip install -r requirements.txt
#    ```
#
# 2. **Run the Application**
#
#    Execute the application by running:
#
#    ```
#    python app.py
#    ```
#
# 3. **Using the Application**
#
#    - Enter your question at the prompt.
#    - If the application finds a close match, it will display the existing answer.
#    - If not, you'll be prompted to provide an answer, which will be saved for future queries.
#    - Type `'exit'` to quit the application.
#
# **Note:**
#
# - The similarity threshold in `app.py` (currently set at 80%) can be adjusted based on how strict you want the matching to be.
# - The database file `qa_database.db` is stored in the `data/` directory.
# - You can enhance the matching algorithm or database interactions by modifying `matching.py` and `database.py` respectively.
#
# Feel free to expand upon this basic framework to add more features or improve functionality as needed.
