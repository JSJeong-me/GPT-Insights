# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/GPT-Insights/blob/main/o1-planning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai==1.54.0 httpx==0.27.2
# Out:
# Collecting openai==1.54.0
#   Downloading openai-1.54.0-py3-none-any.whl.metadata (24 kB)
# Collecting httpx==0.27.2
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.54.0) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.54.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.54.0) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.54.0) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai==1.54.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai==1.54.0) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai==1.54.0) (4.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.2) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.2) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.2) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx==0.27.2) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.54.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.54.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.54.0) (0.4.1)
# Downloading openai-1.54.0-py3-none-any.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.3/389.3 kB 37.1 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: httpx, openai
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: openai
#     Found existing installation: openai 1.106.1
#     Uninstalling openai-1.106.1:
#       Successfully uninstalled openai-1.106.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.33.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# firebase-admin 6.9.0 requires httpx[http2]==0.28.1, but you have httpx 0.27.2 which is incompatible.
# Successfully installed httpx-0.27.2 openai-1.54.0

# %%
from google.colab import userdata
import os

# userdata.get('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
from openai import OpenAI

client = OpenAI(api_key=openai_api_key)

prompt = """
I want to build a Python app that takes user questions and looks
them up in a database where they are mapped to answers. If there
is close match, it retrieves the matched answer. If there isn't,
it asks the user to provide an answer and stores the
question/answer pair in the database. Make a plan for the directory
structure you'll need, then return each file in full. Only supply
your reasoning at the beginning and end, not throughout the code.
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": prompt
                },
            ],
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# To build a Python app that captures user questions, retrieves answers from a database, and stores new question/answer pairs, we need a structured directory layout to maintain organization and clarity. Here's a proposed directory structure:
#
# ```
# my_question_answer_app/
# ├── app.py
# ├── database.py
# ├── models.py
# ├── utils.py
# ├── requirements.txt
# ├── data/
# │   └── qa_pairs.db
# └── README.md
# ```
#
# ### Explanation of the Directory Structure
#
# - **app.py**: This is the main application file where the logic for user interaction will be implemented.
# - **database.py**: This file will handle all database interactions, including querying and saving question/answer pairs.
# - **models.py**: This file can define the data structure for questions and answers.
# - **utils.py**: This will include utility functions such as string similarity or other helper functions.
# - **requirements.txt**: This file lists all external libraries required to run the application.
# - **data/**: This directory will contain the SQLite database file (`qa_pairs.db`) which stores our question and answer pairs.
# - **README.md**: A markdown file for documentation, explaining how to set up and run the application.
#
# Now, I will provide the code for each of these files.
#
# ---
#
# ### app.py
#
# ```python
# import sqlite3
# from database import get_answer, save_qa_pair
# from utils import get_user_input, find_closest_match
#
# def main():
#     while True:
#         user_question = get_user_input("Please enter your question (or type 'exit' to quit): ")
#         if user_question.lower() == 'exit':
#             break
#
#         answer = get_answer(user_question)
#         if answer:
#             print(f"Answer: {answer}")
#         else:
#             print("I don't have an answer for that. Please provide an answer:")
#             user_answer = get_user_input("Your answer: ")
#             save_qa_pair(user_question, user_answer)
#             print("Thank you! Your question and answer have been saved.")
#
# if __name__ == "__main__":
#     main()
# ```
#
# ### database.py
#
# ```python
# import sqlite3
#
# DATABASE_PATH = 'data/qa_pairs.db'
#
# def connect_db():
#     return sqlite3.connect(DATABASE_PATH)
#
# def setup_database():
#     with connect_db() as conn:
#         conn.execute('''
#             CREATE TABLE IF NOT EXISTS qa_pairs (
#                 id INTEGER PRIMARY KEY,
#                 question TEXT UNIQUE,
#                 answer TEXT
#             )
#         ''')
#
# def get_answer(user_question):
#     with connect_db() as conn:
#         cursor = conn.cursor()
#         cursor.execute("SELECT answer FROM qa_pairs WHERE question=?", (user_question,))
#         result = cursor.fetchone()
#         return result[0] if result else None
#
# def save_qa_pair(question, answer):
#     with connect_db() as conn:
#         conn.execute("INSERT OR IGNORE INTO qa_pairs (question, answer) VALUES (?, ?)", (question, answer))
# ```
#
# ### models.py
#
# ```python
# class QAPair:
#     def __init__(self, question: str, answer: str):
#         self.question = question
#         self.answer = answer
#
#     def __repr__(self):
#         return f"QAPair(question={self.question}, answer={self.answer})"
# ```
#
# ### utils.py
#
# ```python
# def get_user_input(prompt):
#     return input(prompt)
#
# def find_closest_match(user_question, question_list):
#     # Placeholder for a string similarity function (e.g., Levenshtein distance)
#     return None  # Implement actual similarity calculation if needed
# ```
#
# ### requirements.txt
#
# ```
# sqlite3
# ```
#
# ### README.md
#
# ```markdown
# # My Question-Answer App
#
# ## Overview
# This is a simple Python application that allows users to ask questions. The app retrieves answers from a local database. If the question does not have a stored answer, it prompts the user to provide the answer, which is then saved for future reference.
#
# ## Directory Structure
# ```
# my_question_answer_app/
# ├── app.py
# ├── database.py
# ├── models.py
# ├── utils.py
# ├── requirements.txt
# ├── data/
# │   └── qa_pairs.db
# └── README.md
# ```
#
# ## Setup
# 1. Clone the repository.
# 2. Navigate to the project directory.
# 3. Run `python app.py` to start the application.
# 4. Follow the prompts to input questions and answers.
#
# ## Requirements
# Make sure to install any necessary packages listed in `requirements.txt` (if using external packages in future projects).
# ```
#
# ---
#
# This structure and implementation will provide a solid foundation for the question-answering Python application. You may want to enhance it with more features such as improved string matching and error handling as you further develop the app.
